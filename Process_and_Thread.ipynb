# %% [markdown]
# <a href="https://colab.research.google.com/github/ngobaongoc61/DN-59/blob/master/Process_and_Thread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. Write and Combine C program**

# %%
# %%writefile sample.cpp
#
# #include <stdio.h>
# #define NAME "LUCAS"
#
# int main()
# {
#     printf("Hello world, %s!", NAME); // In dong chu "Hello world"
#
#     return 0;
# }
# Out:
# Overwriting sample.cpp

# %% [markdown]
# Compile file sample.cpp and then run it using shell command.

# %%
# !g++ sample.cpp -o sample
# !./sample
# Out:
# Hello world, LUCAS!

# %% [markdown]
# **Example about command line arguments in C**

# %%
# %%writefile test_arg.cpp
#
# #include <stdio.h>
# #include <stdlib.h>
#
# int main(int argc, char* argv[])
# {
#     if (argc < 2)
#     {
#         printf("We cannot find the name from command line!");
#     }
#     else
#         printf("Hello world, %s %s\n", argv[1], argv[2]);
#     return 0;
# }
# Out:
# Overwriting test_arg.cpp

# %%
# !g++ test_arg.cpp -o test_arg
# !./test_arg
# Out:
# We cannot find the name from command line!

# %%
# !./test_arg "Lucas Tran"
# Out:
# Hello world, Lucas Tran (null)

# %% [markdown]
# # Làm sao để chạy code C?

# %% [markdown]
# ## Chạy chương trình C cơ bản

# %% [markdown]
# Để chạy code C, chúng ta cần thực hiện các bước như sau:
#
#
# 1.   Tạo ra file source code thông qua magic cell `%%writefile`
# 2.   Biên dịch file source code, để chuyển từ source code thành file khả thực thi, sử dụng câu lệnh `gcc` đối với file C và `g++` đối với file C++
# 3.   Thực thi file khả thực thi thông qua địa chỉ của file

# %%
# %%writefile sample.cpp
#
# #include<stdio.h>
#
# int main()
# {
#     printf("Hello world, I am Tran Hoang Loc");
#
#     return 0;
# }
# Out:
# Overwriting sample.cpp

# %%
# !g++ sample.cpp -o sample

# %%
# !./sample
# Out:
# Hello world, I am Tran Hoang Loc

# %% [markdown]
# ## Truyền tham số dòng lệnh cho chương trình C

# %% [markdown]
# Tham số của chương trình C được nhận thông qua 2 thành phần:
#
#
# *   **argc**: viết tắt của argument count, tức là số tham số dòng lệnh được truyền vào chương trình
# *   **argv[]**: mảng lưu các tham số dòng lệnh
# *   Tham số dòng lệnh được nhận từ hàm main theo cấu trúc khai báo sau `int main(int argc, char* argv[])`

# %%
# %%writefile test_arg.cpp
#
# #include<stdio.h>
#
# int main(int argc, char* argv[])
# {
#     printf("So luong tham so tren dong lenh: %d\n", argc);
#
#     for (int i = 0; i < argc; i++)
#         printf("argv[%d]: %s\n", i, argv[i]);
#
#     return 0;
# }
# Out:
# Overwriting test_arg.cpp

# %%
# !g++ test_arg.cpp -o test_arg
# !./test_arg
# Out:
# So luong tham so tren dong lenh: 1
# argv[0]: ./test_arg

# %% [markdown]
# `argv[0]` (phần tử đầu tiên trong mảng `argv[]`) chính là tên chương trình

# %%
# !./test_arg "Tran Hoang Loc"
# Out:
# So luong tham so tren dong lenh: 2
# argv[0]: ./test_arg
# argv[1]: Tran Hoang Loc

# %% [markdown]
# Lưu ý: tham số dòng lệnh được truyền theo dạng chuỗi (string), do đó, nếu cần xử lý dạng số thì cần phải chuyển từ chuỗi về số trước.

# %% [markdown]
# # **1. Process Creation**

# %% [markdown]
# ## **1.1. Create process with `fork()`**

# %%
# %%writefile test_fork.cpp
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
# #include <sys/wait.h>
# #include <sys/types.h>
#
# int main(int argc, char* argv[])
# {
#     __pid_t pid;
#     pid = fork();
#
#     if (pid > 0)
#     {
#         printf("PARENTS | PID = %ld | PPID = %ld\n",
#         (long)getpid(), (long)getppid());
#
#         if (argc > 2)
#         {
#             printf("PARENTS | There are %d arguments\n", argc - 1);
#             wait(NULL);
#         }
#     }
#     if (pid == 0)
#     {
#         printf("CHILDREN | PID = %ld | PPID = %ld\n",
#         (long)getpid(), (long)getppid());
#
#         printf("CHILDREN | List of arguments: \n");
#
#         for (int i = 1; i < argc; i++)
#         {
#             printf("%s\n", argv[i]);
#         }
#     }
#
#     return 0;
# }
# Out:
# Overwriting test_fork.cpp

# %%
# !g++ test_fork.cpp -o test_fork
# !./test_fork ThamSo1 ThamSo2 ThamSo3
# Out:
# PARENTS | PID = 87192 | PPID = 26787
# PARENTS | There are 3 arguments
# CHILDREN | PID = 87193 | PPID = 87192
# CHILDREN | List of arguments:
# ThamSo1
# ThamSo2
# ThamSo3

# %% [markdown]
# ## **1.2. Create process with `exec()`**

# %% [markdown]
# **Firstly, create `count.sh` which do following tasks:**
#
# *   Print process name
# *   Print PPID (parent's process ID)
# *   Count from 1 to $1 while printing numbers to `count.txt`
#
# *Notes: the command `ps -ef | grep count.sh` lists all processes and then find which line (process' info) contains string "count.sh". This command helps us find information (PID and PPID) of process `./count.sh`*

# %%
# %%writefile count.sh
#
# #!/bin/bash
#
# echo "Implementing: $0"
# echo "PPID of count.sh: "
# ps -ef | grep count.sh
#
# i=1
#
# while [ $i -le $1 ]
# do
#     echo $i >> count.txt
#     i=$((i + 1))
#     sleep 1
# done
#
# exit 0
# Out:
# Writing count.sh

# %% [markdown]
# We have to grant execution permission to count.sh in order to execute it. We only do this once.

# %%
# !chmod 755 count.sh

# %% [markdown]
# Run the script (with $1 = 20) and check result if count.txt is created/updated.

# %%
# !./count.sh 20
# Out:
# Implementing: ./count.sh
# PPID of count.sh:
# root       89839   26787  0 08:48 ?        00:00:00 /bin/bash -c ./count.sh 20
# root       89841   89839  0 08:48 ?        00:00:00 grep count.sh

# %% [markdown]
# **Create `test_execl.cpp`, compile and run it**

# %%
# %%writefile test_execl.cpp
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
# #include <sys/wait.h>
# #include <sys/types.h>
#
# int main(int argc, char* argv[])
# {
#     __pid_t pid;
#     pid = fork();
#     if (pid > 0)
#     {
#         printf("PARENTS | PID = %ld | PPID = %ld\n",
#         (long)getpid(), (long)getppid());
#
#         if (argc > 2)
#             printf("PARENTS | There are %d arguments\n",
#             argc - 1);
#         wait(NULL);
#     }
#     if (pid == 0)
#     {
#         execlp("./count.sh", "./count.sh", "10", NULL);
#
#         printf("CHILDREN | PID = %ld | PPID = %ld\n",
#         (long)getpid(), (long)getppid());
#
#         printf("CHILDREN | List of arguments: \n");
#
#         for (int i = 1; i < argc; i++)
#         {
#             printf("%s\n", argv[i]);
#         }
#     }
#
#     return 0;
# }
# Out:
# Overwriting test_execl.cpp

# %%
# !g++ test_execl.cpp -o test_execl
# !./test_execl ThamSo1 ThamSo2
# Out:
# PARENTS | PID = 90859 | PPID = 26787
# PARENTS | There are 2 arguments
# Implementing: ./count.sh
# PPID of count.sh:
# root       90860   90859  0 08:53 ?        00:00:00 /bin/sh ./count.sh 10
# root       90862   90860  0 08:53 ?        00:00:00 grep count.sh

# %% [markdown]
# ## **1.3. Create process with `system()`**

# %% [markdown]
# **Create `test_system.cpp`, compile and run it**

# %%
# %%writefile test_system.cpp
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
# #include <sys/wait.h>
# #include <sys/types.h>
#
# int main(int argc, char* argv[])
# {
#     printf("PARENTS | PID = %ld | PPID = %ld\n",
#     (long)getpid(), (long)getppid());
#
#     if (argc > 2)
#         printf("PARENTS | There are %d arguments\n", argc
#         - 1);
#
#     system("./count.sh 10");
#
#     printf("PARENTS | List of arguments: \n");
#
#     for (int i = 1; i < argc; i++)
#     {
#         printf("%s\n", argv[i]);
#     }
#
#     return 0;
# }
# Out:
# Writing test_system.cpp

# %%
# !g++ test_system.cpp -o test_system
# !./test_system ThamSo1 ThamSo2 ThamSo3
# Out:
# PARENTS | PID = 575 | PPID = 225
# PARENTS | There are 3 arguments
# Implementing: ./count.sh
# PPID of count.sh:
# root         576     575  0 14:00 ?        00:00:00 sh -c ./count.sh 10
# root         577     576  0 14:00 ?        00:00:00 /bin/sh ./count.sh 10
# root         579     577  0 14:00 ?        00:00:00 grep count.sh
# PARENTS | List of arguments:
# ThamSo1
# ThamSo2
# ThamSo3

# %% [markdown]
# ## **BÀI TẬP**

# %% [markdown]
# ### **Bài tập 1.** Hãy giải thích cơ chế tạo tiến trình của hàm `fork()`, `exec()`, và `system()`

# %% [markdown]
# ### **Bài tập 2.** So sánh sự giống và khác nhau của 3 cách tạo tiến trình trên

# %% [markdown]
# # **2. Working with Threads**

# %% [markdown]
# ## **2.1. Thread creation**

# %%
# %%writefile thread_creation.cpp
#
# #include <pthread.h>
# #include <stdio.h>
#
# void *thread_print(void *message)
# {
#     while(1)
#         printf("Hello, how are you?\n");
# }
#
# int main()
# {
#     pthread_t idthread;
#
#     pthread_create(
#         &idthread,
#         NULL,
#         &thread_print,
#         NULL
#     );
#
#     while(1)
#         printf("I'm fine, and you?\n");
#
#     return 0;
# }
# Out:
# Writing thread_creation.cpp

# %%
# !gcc thread_creation.cpp -o thread_creation
# !./thread_creation
# Out:
# Streaming output truncated to the last 5000 lines.
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# ...
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# I'm fine, and you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# Hello, how are you?
# ^C

# %% [markdown]
# ## **2.2. Stop threads**

# %%
# %%writefile thread_selfexit.c
#
# #include <pthread.h>
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
#
# #define NUM_THREADS 2
#
# void *thread_print(void *threadid)
# {
#     long tid;
#     tid = (long)threadid;
#     printf("Hello IT007! I'm Thread #%ld!\n", tid);
#     pthread_exit(NULL);
# }
#
# int main()
# {
#     pthread_t threads[NUM_THREADS];
#     int check;
#     long tID;
#
#     for(tID = 0; tID < NUM_THREADS; tID++)
#     {
#         check = pthread_create(
#                     &threads[tID],
#                     NULL,
#                     &thread_print,
#                     (void *)tID
#                 );
#
#         if (check != 0)
#         {
#             printf("[MAIN_THREAD] ERROR! Can't create Thread #%ld\n", tID);
#             exit(-1);
#         }
#     }
#
#
#     sleep(10);
#
#     printf("[MAIN THREAD] Bye bye!\n");
#     pthread_exit(NULL);
#     return 0;
# }
# Out:
# Writing thread_selfexit.c

# %%
# !gcc thread_selfexit.c -o thread_selfexit
# !./thread_selfexit
# Out:
# Hello IT007! I'm Thread #1!
# Hello IT007! I'm Thread #0!
# [MAIN THREAD] Bye bye!

# %% [markdown]
# ## **2.3. Merge threads**

# %%
# %%writefile thread_join.c
#
# #include <pthread.h>
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
#
# #define NUM_THREADS 2
#
# void *thread_print(void *threadid)
# {
#     long tid;
#     tid = (long)threadid;
#     printf("Hello IT007! I'm Thread #%ld!\n", tid);
#     sleep(10);
# }
#
# int main()
# {
#     pthread_t threads[NUM_THREADS];
#     int check;
#     long tID;
#
#     for(tID = 0; tID < NUM_THREADS; tID++)
#     {
#         printf("[MAIN THREAD] Create Thread #%ld\n", tID);
#         check = pthread_create(
#                     &threads[tID],
#                     NULL,
#                     &thread_print,
#                     (void *)tID
#                 );
#
#         if (check != 0)
#         {
#             printf("[MAIN_THREAD] ERROR! Can't create Thread #%ld\n", tID);
#             exit(-1);
#         }
#
#         pthread_join(threads[tID], NULL);
#     }
#
#     printf("[MAIN THREAD] Bye bye!\n");
#     pthread_exit(NULL);
#     return 0;
# }
# Out:
# Overwriting thread_join.c

# %%
# !gcc thread_join.c -o thread_join
# !./thread_join
# Out:
# [MAIN THREAD] Create Thread #0
# Hello IT007! I'm Thread #0!
# [MAIN THREAD] Create Thread #1
# Hello IT007! I'm Thread #1!
# [MAIN THREAD] Bye bye!

# %% [markdown]
# ## **2.4. Send arguments to thread**

# %%
# %%writefile thread_args.c
#
# #include <pthread.h>
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
#
# struct print_params
# {
#     char character;
#     int count;
# };
#
# void *char_print(void* args)
# {
#     struct print_params *p = (struct print_params *)args;
#     int i;
#
#     for (i = 0; i < p->count; i++)
#         printf("%c\n", p->character);
#
#     return NULL;
# }
#
# int main()
# {
#     pthread_t tid;
#     struct print_params th_args;
#
#     th_args.character = 'X';
#     th_args.count = 5;
#
#     pthread_create(
#         &tid,
#         NULL,
#         &char_print,
#         &th_args
#     );
#
#     pthread_join(tid, NULL);
#
#     pthread_exit(NULL);
#     return 0;
# }
# Out:
# Overwriting thread_args.c

# %%
# !gcc thread_args.c -o thread_args
# !./thread_args
# Out:
# X
# X
# X
# X
# X

# %% [markdown]
# # **3. Đồng bộ tiểu trình**

# %% [markdown]
# ## **3.1. Mutex Locks**

# %% [markdown]
# Cho 2 tiến trình (hoặc tiểu trình) cùng thực hiện một công việc như bên dưới:
#
# ```
# x = x + 1;
# if (x == 20)
#     x = 0;
# ```

# %%
# %%writefile mutex_example.cpp
#
# #include <pthread.h>
# #include <stdio.h>
#
# int x = 0; // Bien toan cuc, duoc chia se giua A va B
# pthread_mutex_t mut; // Khai bao mutex toan cuc
#
# void *ProcessA(void *message)
# {
#     while(1)
#     {
#         pthread_mutex_lock(&mut); // Lock mutex
#         x = x + 1;
#         if (x == 20)
#             x = 0;
#         printf("Process A | x = %d\n", x);
#         pthread_mutex_unlock(&mut); // Unlock mutex
#     }
# }
#
# void *ProcessB(void *message)
# {
#     while(1)
#     {
#         pthread_mutex_lock(&mut); // Lock mutex
#         x = x + 1;
#         if (x == 20)
#             x = 0;
#         printf("Process B | x = %d\n", x);
#         pthread_mutex_unlock(&mut); // Unlock mutex
#     }
# }
#
# int main()
# {
#     pthread_t idthreadA, idthreadB;
#     pthread_mutex_init(&mut, NULL); // Khoi tao mutex
#
#     pthread_create(
#         &idthreadA,
#         NULL,
#         &ProcessA,
#         NULL
#     );
#
#     pthread_create(
#         &idthreadB,
#         NULL,
#         &ProcessB,
#         NULL
#     );
#
#     while(1){}
#
#     return 0;
# }
# Out:
# Overwriting mutex_example.cpp

# %%
# !g++ mutex_example.cpp -o mutex_example

# %%
# !./mutex_example
# Out:
# Streaming output truncated to the last 5000 lines.
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# ...
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process A | x = 10
# Process A | x = 11
# Process A | x = 12
# Process A | x = 13
# Process A | x = 14
# Process A | x = 15
# Process A | x = 16
# Process A | x = 17
# Process A | x = 18
# Process A | x = 19
# Process A | x = 0
# Process A | x = 1
# Process A | x = 2
# Process A | x = 3
# Process A | x = 4
# Process A | x = 5
# Process A | x = 6
# Process A | x = 7
# Process A | x = 8
# Process A | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# Process B | x = 5
# Process B | x = 6
# Process B | x = 7
# Process B | x = 8
# Process B | x = 9
# Process B | x = 10
# Process B | x = 11
# Process B | x = 12
# Process B | x = 13
# Process B | x = 14
# Process B | x = 15
# Process B | x = 16
# Process B | x = 17
# Process B | x = 18
# Process B | x = 19
# Process B | x = 0
# Process B | x = 1
# Process B | x = 2
# Process B | x = 3
# Process B | x = 4
# ^C

# %% [markdown]
# ## **3.2. Semaphores**

# %% [markdown]
# Cho 02 tiến trình Produce và Consume như sau:
# ```
# Produce()
# {
#     products++;
# }
# ```
# ```
# Consume()
# {
#     sells++;
# }
# ```
# Ta có điều kiện là tại mọi thời điểm `products >= sells`
# Do sells chỉ được phép tăng khi `sells < products`, và được tăng tối đa một lượng bằng `products - sells`. Gọi semaphore `stock` được khởi tạo bằng `products - sells`.

# %%
# %%writefile semaphore_example.cpp
#
# #include <pthread.h>
# #include <stdio.h>
# #include <semaphore.h>
#
# int products = 0, sells = 0; // Bien toan cuc, duoc chia se giua A va B
# sem_t stock; // Khai bao semaphore la toan cuc
#
# void *Produce(void *message)
# {
#     while(1)
#     {
#         products++;
#         printf("Produce | products = %d\n", products);
#         sem_post(&stock); // Thao tac signal semaphore
#     }
# }
#
# void *Consume(void *message)
# {
#     while(1)
#     {
#         sem_wait(&stock); // Thao tac wait semaphore
#         sells++;
#         printf("Consume | sells = %d\n", sells);
#     }
# }
#
# int main()
# {
#     pthread_t idthreadA, idthreadB;
#     sem_init(&stock, 0, products - sells); // Gia tri khoi tao cua stock la products - sells
#
#     pthread_create(
#         &idthreadA,
#         NULL,
#         &Produce,
#         NULL
#     );
#
#     pthread_create(
#         &idthreadB,
#         NULL,
#         &Consume,
#         NULL
#     );
#
#     while(1){}
#
#     return 0;
# }
# Out:
# Overwriting semaphore_example.cpp

# %%
# !g++ semaphore_example.cpp -o semaphore_example

# %%
# !./semaphore_example
# Out:
# Streaming output truncated to the last 5000 lines.
# Consume | sells = 67536
# Consume | sells = 67537
# Consume | sells = 67538
# Consume | sells = 67539
# Consume | sells = 67540
# Consume | sells = 67541
# Consume | sells = 67542
# Consume | sells = 67543
# Consume | sells = 67544
# Consume | sells = 67545
# Consume | sells = 67546
# Consume | sells = 67547
# Consume | sells = 67548
# Consume | sells = 67549
# Consume | sells = 67550
# Consume | sells = 67551
# Consume | sells = 67552
# Consume | sells = 67553
# Consume | sells = 67554
# Consume | sells = 67555
# Consume | sells = 67556
# Consume | sells = 67557
# Consume | sells = 67558
# Consume | sells = 67559
# Consume | sells = 67560
# Consume | sells = 67561
# Consume | sells = 67562
# Consume | sells = 67563
# Consume | sells = 67564
# Consume | sells = 67565
# Consume | sells = 67566
# Consume | sells = 67567
# Consume | sells = 67568
# Consume | sells = 67569
# Consume | sells = 67570
# Consume | sells = 67571
# Consume | sells = 67572
# Consume | sells = 67573
# Consume | sells = 67574
# Consume | sells = 67575
# Consume | sells = 67576
# Consume | sells = 67577
# Consume | sells = 67578
# Consume | sells = 67579
# Consume | sells = 67580
# Consume | sells = 67581
# Consume | sells = 67582
# Consume | sells = 67583
# Consume | sells = 67584
# Consume | sells = 67585
# Consume | sells = 67586
# Consume | sells = 67587
# Consume | sells = 67588
# Consume | sells = 67589
# Consume | sells = 67590
# Consume | sells = 67591
# Consume | sells = 67592
# Consume | sells = 67593
# Consume | sells = 67594
# Consume | sells = 67595
# Consume | sells = 67596
# Consume | sells = 67597
# Consume | sells = 67598
# Consume | sells = 67599
# Consume | sells = 67600
# Consume | sells = 67601
# Consume | sells = 67602
# Consume | sells = 67603
# Consume | sells = 67604
# Consume | sells = 67605
# Consume | sells = 67606
# Consume | sells = 67607
# Consume | sells = 67608
# Consume | sells = 67609
# Consume | sells = 67610
# Consume | sells = 67611
# Consume | sells = 67612
# Consume | sells = 67613
# Consume | sells = 67614
# Consume | sells = 67615
# Consume | sells = 67616
# Consume | sells = 67617
# Consume | sells = 67618
# Consume | sells = 67619
# Consume | sells = 67620
# Consume | sells = 67621
# Consume | sells = 67622
# Consume | sells = 67623
# Consume | sells = 67624
# Consume | sells = 67625
# Consume | sells = 67626
# Consume | sells = 67627
# Consume | sells = 67628
# Consume | sells = 67629
# Consume | sells = 67630
# Consume | sells = 67631
# Consume | sells = 67632
# Consume | sells = 67633
# Consume | sells = 67634
# Consume | sells = 67635
# Consume | sells = 67636
# Consume | sells = 67637
# Consume | sells = 67638
# Consume | sells = 67639
# Consume | sells = 67640
# Consume | sells = 67641
# Consume | sells = 67642
# Consume | sells = 67643
# Consume | sells = 67644
# Consume | sells = 67645
# Consume | sells = 67646
# Consume | sells = 67647
# Consume | sells = 67648
# Consume | sells = 67649
# Consume | sells = 67650
# Consume | sells = 67651
# Consume | sells = 67652
# Consume | sells = 67653
# Consume | sells = 67654
# Consume | sells = 67655
# Consume | sells = 67656
# Consume | sells = 67657
# Consume | sells = 67658
# Consume | sells = 67659
# Consume | sells = 67660
# Consume | sells = 67661
# Consume | sells = 67662
# Consume | sells = 67663
# Consume | sells = 67664
# Consume | sells = 67665
# Consume | sells = 67666
# Consume | sells = 67667
# Consume | sells = 67668
# Consume | sells = 67669
# Consume | sells = 67670
# Consume | sells = 67671
# Consume | sells = 67672
# Consume | sells = 67673
# Consume | sells = 67674
# Consume | sells = 67675
# Consume | sells = 67676
# Consume | sells = 67677
# Consume | sells = 67678
# Consume | sells = 67679
# Consume | sells = 67680
# Consume | sells = 67681
# Consume | sells = 67682
# Consume | sells = 67683
# Consume | sells = 67684
# Consume | sells = 67685
# Consume | sells = 67686
# Consume | sells = 67687
# Consume | sells = 67688
# Consume | sells = 67689
# Consume | sells = 67690
# Consume | sells = 67691
# Consume | sells = 67692
# Consume | sells = 67693
# Consume | sells = 67694
# Consume | sells = 67695
# Consume | sells = 67696
# Consume | sells = 67697
# Consume | sells = 67698
# Consume | sells = 67699
# Consume | sells = 67700
# Consume | sells = 67701
# Consume | sells = 67702
# Consume | sells = 67703
# Consume | sells = 67704
# Consume | sells = 67705
# Consume | sells = 67706
# Consume | sells = 67707
# Consume | sells = 67708
# Consume | sells = 67709
# Consume | sells = 67710
# Consume | sells = 67711
# Consume | sells = 67712
# Consume | sells = 67713
# Consume | sells = 67714
# Consume | sells = 67715
# Consume | sells = 67716
# Consume | sells = 67717
# Consume | sells = 67718
# Consume | sells = 67719
# Consume | sells = 67720
# Consume | sells = 67721
# Consume | sells = 67722
# Consume | sells = 67723
# Consume | sells = 67724
# Consume | sells = 67725
# Consume | sells = 67726
# Consume | sells = 67727
# Consume | sells = 67728
# Consume | sells = 67729
# Consume | sells = 67730
# Consume | sells = 67731
# Consume | sells = 67732
# Consume | sells = 67733
# Consume | sells = 67734
# Consume | sells = 67735
# Consume | sells = 67736
# Consume | sells = 67737
# Consume | sells = 67738
# Consume | sells = 67739
# Consume | sells = 67740
# Consume | sells = 67741
# Consume | sells = 67742
# Consume | sells = 67743
# Consume | sells = 67744
# Consume | sells = 67745
# Consume | sells = 67746
# Consume | sells = 67747
# Consume | sells = 67748
# Consume | sells = 67749
# Consume | sells = 67750
# Consume | sells = 67751
# Consume | sells = 67752
# Consume | sells = 67753
# Consume | sells = 67754
# Consume | sells = 67755
# Consume | sells = 67756
# Consume | sells = 67757
# Consume | sells = 67758
# Consume | sells = 67759
# Consume | sells = 67760
# Consume | sells = 67761
# Consume | sells = 67762
# Consume | sells = 67763
# Consume | sells = 67764
# Consume | sells = 67765
# Consume | sells = 67766
# Consume | sells = 67767
# Consume | sells = 67768
# Consume | sells = 67769
# Consume | sells = 67770
# Consume | sells = 67771
# Consume | sells = 67772
# Consume | sells = 67773
# Consume | sells = 67774
# Consume | sells = 67775
# Consume | sells = 67776
# Consume | sells = 67777
# Consume | sells = 67778
# Consume | sells = 67779
# Consume | sells = 67780
# Consume | sells = 67781
# Consume | sells = 67782
# Consume | sells = 67783
# Consume | sells = 67784
# Consume | sells = 67785
# Consume | sells = 67786
# Consume | sells = 67787
# Consume | sells = 67788
# Consume | sells = 67789
# Consume | sells = 67790
# Consume | sells = 67791
# Consume | sells = 67792
# Consume | sells = 67793
# Consume | sells = 67794
# Consume | sells = 67795
# Consume | sells = 67796
# Consume | sells = 67797
# Consume | sells = 67798
# Consume | sells = 67799
# Consume | sells = 67800
# Consume | sells = 67801
# Consume | sells = 67802
# Consume | sells = 67803
# Consume | sells = 67804
# Consume | sells = 67805
# Consume | sells = 67806
# Consume | sells = 67807
# Consume | sells = 67808
# Consume | sells = 67809
# Consume | sells = 67810
# Consume | sells = 67811
# Consume | sells = 67812
# Consume | sells = 67813
# Consume | sells = 67814
# Consume | sells = 67815
# Consume | sells = 67816
# Consume | sells = 67817
# Consume | sells = 67818
# Consume | sells = 67819
# Consume | sells = 67820
# Consume | sells = 67821
# Consume | sells = 67822
# Consume | sells = 67823
# Consume | sells = 67824
# Consume | sells = 67825
# Consume | sells = 67826
# Consume | sells = 67827
# Consume | sells = 67828
# Consume | sells = 67829
# Consume | sells = 67830
# Consume | sells = 67831
# Consume | sells = 67832
# Consume | sells = 67833
# Consume | sells = 67834
# Consume | sells = 67835
# Consume | sells = 67836
# Consume | sells = 67837
# Consume | sells = 67838
# Consume | sells = 67839
# Consume | sells = 67840
# Consume | sells = 67841
# Consume | sells = 67842
# Consume | sells = 67843
# Consume | sells = 67844
# Consume | sells = 67845
# Consume | sells = 67846
# Consume | sells = 67847
# Consume | sells = 67848
# Consume | sells = 67849
# Consume | sells = 67850
# Consume | sells = 67851
# Consume | sells = 67852
# Consume | sells = 67853
# Consume | sells = 67854
# Consume | sells = 67855
# Consume | sells = 67856
# Consume | sells = 67857
# Consume | sells = 67858
# Consume | sells = 67859
# Consume | sells = 67860
# Consume | sells = 67861
# Consume | sells = 67862
# Consume | sells = 67863
# Consume | sells = 67864
# Consume | sells = 67865
# Consume | sells = 67866
# Consume | sells = 67867
# Consume | sells = 67868
# Consume | sells = 67869
# Consume | sells = 67870
# Consume | sells = 67871
# Consume | sells = 67872
# Consume | sells = 67873
# Consume | sells = 67874
# Consume | sells = 67875
# Consume | sells = 67876
# Consume | sells = 67877
# Consume | sells = 67878
# Consume | sells = 67879
# Consume | sells = 67880
# Consume | sells = 67881
# Consume | sells = 67882
# Consume | sells = 67883
# Consume | sells = 67884
# Consume | sells = 67885
# Consume | sells = 67886
# Consume | sells = 67887
# Consume | sells = 67888
# Consume | sells = 67889
# Consume | sells = 67890
# Consume | sells = 67891
# Consume | sells = 67892
# Consume | sells = 67893
# Consume | sells = 67894
# Consume | sells = 67895
# Consume | sells = 67896
# Consume | sells = 67897
# Consume | sells = 67898
# Consume | sells = 67899
# Consume | sells = 67900
# Consume | sells = 67901
# Consume | sells = 67902
# Consume | sells = 67903
# Consume | sells = 67904
# Consume | sells = 67905
# Consume | sells = 67906
# Consume | sells = 67907
# Consume | sells = 67908
# Consume | sells = 67909
# Consume | sells = 67910
# Consume | sells = 67911
# Consume | sells = 67912
# Consume | sells = 67913
# Consume | sells = 67914
# Consume | sells = 67915
# Consume | sells = 67916
# Consume | sells = 67917
# Consume | sells = 67918
# Consume | sells = 67919
# Consume | sells = 67920
# Consume | sells = 67921
# Consume | sells = 67922
# Consume | sells = 67923
# Consume | sells = 67924
# Consume | sells = 67925
# Consume | sells = 67926
# Consume | sells = 67927
# Consume | sells = 67928
# Consume | sells = 67929
# Consume | sells = 67930
# Consume | sells = 67931
# Consume | sells = 67932
# Consume | sells = 67933
# Consume | sells = 67934
# Consume | sells = 67935
# Consume | sells = 67936
# Consume | sells = 67937
# Consume | sells = 67938
# Consume | sells = 67939
# Consume | sells = 67940
# Consume | sells = 67941
# Consume | sells = 67942
# Consume | sells = 67943
# Consume | sells = 67944
# Consume | sells = 67945
# Consume | sells = 67946
# Consume | sells = 67947
# Consume | sells = 67948
# Consume | sells = 67949
# Consume | sells = 67950
# Consume | sells = 67951
# Consume | sells = 67952
# Consume | sells = 67953
# Consume | sells = 67954
# Consume | sells = 67955
# Consume | sells = 67956
# Consume | sells = 67957
# Consume | sells = 67958
# Consume | sells = 67959
# Consume | sells = 67960
# Consume | sells = 67961
# Consume | sells = 67962
# Consume | sells = 67963
# Consume | sells = 67964
# Consume | sells = 67965
# Consume | sells = 67966
# Consume | sells = 67967
# Consume | sells = 67968
# Consume | sells = 67969
# Consume | sells = 67970
# Consume | sells = 67971
# Consume | sells = 67972
# Consume | sells = 67973
# Consume | sells = 67974
# Consume | sells = 67975
# Consume | sells = 67976
# Consume | sells = 67977
# Consume | sells = 67978
# Consume | sells = 67979
# Consume | sells = 67980
# Consume | sells = 67981
# Consume | sells = 67982
# Consume | sells = 67983
# Consume | sells = 67984
# Consume | sells = 67985
# Consume | sells = 67986
# Consume | sells = 67987
# Consume | sells = 67988
# Consume | sells = 67989
# Consume | sells = 67990
# Consume | sells = 67991
# Consume | sells = 67992
# Consume | sells = 67993
# Consume | sells = 67994
# Consume | sells = 67995
# Consume | sells = 67996
# Consume | sells = 67997
# Consume | sells = 67998
# Consume | sells = 67999
# Consume | sells = 68000
# Consume | sells = 68001
# Consume | sells = 68002
# Consume | sells = 68003
# Consume | sells = 68004
# Consume | sells = 68005
# Consume | sells = 68006
# Consume | sells = 68007
# Consume | sells = 68008
# Consume | sells = 68009
# Consume | sells = 68010
# Consume | sells = 68011
# Consume | sells = 68012
# Consume | sells = 68013
# Consume | sells = 68014
# Consume | sells = 68015
# Consume | sells = 68016
# Consume | sells = 68017
# Consume | sells = 68018
# Consume | sells = 68019
# Consume | sells = 68020
# Consume | sells = 68021
# Consume | sells = 68022
# Consume | sells = 68023
# Consume | sells = 68024
# Consume | sells = 68025
# Consume | sells = 68026
# Consume | sells = 68027
# Consume | sells = 68028
# Consume | sells = 68029
# Consume | sells = 68030
# Consume | sells = 68031
# Consume | sells = 68032
# Consume | sells = 68033
# Consume | sells = 68034
# Consume | sells = 68035
# Consume | sells = 68036
# Consume | sells = 68037
# Consume | sells = 68038
# Consume | sells = 68039
# Consume | sells = 68040
# Consume | sells = 68041
# Consume | sells = 68042
# Consume | sells = 68043
# Consume | sells = 68044
# Consume | sells = 68045
# Consume | sells = 68046
# Consume | sells = 68047
# Consume | sells = 68048
# Consume | sells = 68049
# Consume | sells = 68050
# Consume | sells = 68051
# Consume | sells = 68052
# Consume | sells = 68053
# Consume | sells = 68054
# Consume | sells = 68055
# Consume | sells = 68056
# Consume | sells = 68057
# Consume | sells = 68058
# Consume | sells = 68059
# Consume | sells = 68060
# Consume | sells = 68061
# Consume | sells = 68062
# Consume | sells = 68063
# Consume | sells = 68064
# Consume | sells = 68065
# Consume | sells = 68066
# Consume | sells = 68067
# Consume | sells = 68068
# Consume | sells = 68069
# Consume | sells = 68070
# Consume | sells = 68071
# Consume | sells = 68072
# Consume | sells = 68073
# Consume | sells = 68074
# Consume | sells = 68075
# Consume | sells = 68076
# Consume | sells = 68077
# Consume | sells = 68078
# Consume | sells = 68079
# Consume | sells = 68080
# Consume | sells = 68081
# Consume | sells = 68082
# Consume | sells = 68083
# Consume | sells = 68084
# Consume | sells = 68085
# Consume | sells = 68086
# Consume | sells = 68087
# Consume | sells = 68088
# Consume | sells = 68089
# Consume | sells = 68090
# Consume | sells = 68091
# Consume | sells = 68092
# Consume | sells = 68093
# Consume | sells = 68094
# Consume | sells = 68095
# Consume | sells = 68096
# Consume | sells = 68097
# Consume | sells = 68098
# Consume | sells = 68099
# Consume | sells = 68100
# Consume | sells = 68101
# Consume | sells = 68102
# Consume | sells = 68103
# Consume | sells = 68104
# Consume | sells = 68105
# Consume | sells = 68106
# Consume | sells = 68107
# Consume | sells = 68108
# Consume | sells = 68109
# Consume | sells = 68110
# Consume | sells = 68111
# Consume | sells = 68112
# Consume | sells = 68113
# Consume | sells = 68114
# Consume | sells = 68115
# Consume | sells = 68116
# Consume | sells = 68117
# Consume | sells = 68118
# Consume | sells = 68119
# Consume | sells = 68120
# Consume | sells = 68121
# Consume | sells = 68122
# Consume | sells = 68123
# Consume | sells = 68124
# Consume | sells = 68125
# Consume | sells = 68126
# Consume | sells = 68127
# Consume | sells = 68128
# Consume | sells = 68129
# Consume | sells = 68130
# Consume | sells = 68131
# Consume | sells = 68132
# Consume | sells = 68133
# Consume | sells = 68134
# Consume | sells = 68135
# Consume | sells = 68136
# Consume | sells = 68137
# Consume | sells = 68138
# Consume | sells = 68139
# Consume | sells = 68140
# Consume | sells = 68141
# Consume | sells = 68142
# Consume | sells = 68143
# Consume | sells = 68144
# Consume | sells = 68145
# Consume | sells = 68146
# Consume | sells = 68147
# Consume | sells = 68148
# Consume | sells = 68149
# Consume | sells = 68150
# Consume | sells = 68151
# Consume | sells = 68152
# Consume | sells = 68153
# Consume | sells = 68154
# Consume | sells = 68155
# Consume | sells = 68156
# Consume | sells = 68157
# Consume | sells = 68158
# Consume | sells = 68159
# Consume | sells = 68160
# Consume | sells = 68161
# Consume | sells = 68162
# Consume | sells = 68163
# Consume | sells = 68164
# Consume | sells = 68165
# Consume | sells = 68166
# Consume | sells = 68167
# Consume | sells = 68168
# Consume | sells = 68169
# Consume | sells = 68170
# Consume | sells = 68171
# Consume | sells = 68172
# Consume | sells = 68173
# Consume | sells = 68174
# Consume | sells = 68175
# Consume | sells = 68176
# Consume | sells = 68177
# Consume | sells = 68178
# Consume | sells = 68179
# Consume | sells = 68180
# Consume | sells = 68181
# Consume | sells = 68182
# Consume | sells = 68183
# Consume | sells = 68184
# Consume | sells = 68185
# Consume | sells = 68186
# Consume | sells = 68187
# Consume | sells = 68188
# Consume | sells = 68189
# Consume | sells = 68190
# Consume | sells = 68191
# Consume | sells = 68192
# Consume | sells = 68193
# Consume | sells = 68194
# Consume | sells = 68195
# Consume | sells = 68196
# Consume | sells = 68197
# Consume | sells = 68198
# Consume | sells = 68199
# Consume | sells = 68200
# Consume | sells = 68201
# Consume | sells = 68202
# Consume | sells = 68203
# Consume | sells = 68204
# Consume | sells = 68205
# Consume | sells = 68206
# Consume | sells = 68207
# Consume | sells = 68208
# Consume | sells = 68209
# Consume | sells = 68210
# Consume | sells = 68211
# Consume | sells = 68212
# Consume | sells = 68213
# Consume | sells = 68214
# Consume | sells = 68215
# Consume | sells = 68216
# Consume | sells = 68217
# Consume | sells = 68218
# Consume | sells = 68219
# Consume | sells = 68220
# Consume | sells = 68221
# Consume | sells = 68222
# Consume | sells = 68223
# Consume | sells = 68224
# Consume | sells = 68225
# Consume | sells = 68226
# Consume | sells = 68227
# Consume | sells = 68228
# Consume | sells = 68229
# Consume | sells = 68230
# Consume | sells = 68231
# Consume | sells = 68232
# Consume | sells = 68233
# Consume | sells = 68234
# Consume | sells = 68235
# Consume | sells = 68236
# Consume | sells = 68237
# Consume | sells = 68238
# Consume | sells = 68239
# Consume | sells = 68240
# Consume | sells = 68241
# Consume | sells = 68242
# Consume | sells = 68243
# Consume | sells = 68244
# Consume | sells = 68245
# Consume | sells = 68246
# Consume | sells = 68247
# Consume | sells = 68248
# Consume | sells = 68249
# Consume | sells = 68250
# Consume | sells = 68251
# Consume | sells = 68252
# Consume | sells = 68253
# Consume | sells = 68254
# Consume | sells = 68255
# Consume | sells = 68256
# Consume | sells = 68257
# Consume | sells = 68258
# Consume | sells = 68259
# Consume | sells = 68260
# Consume | sells = 68261
# Consume | sells = 68262
# Consume | sells = 68263
# Consume | sells = 68264
# Consume | sells = 68265
# Consume | sells = 68266
# Consume | sells = 68267
# Consume | sells = 68268
# Consume | sells = 68269
# Consume | sells = 68270
# Consume | sells = 68271
# Consume | sells = 68272
# Consume | sells = 68273
# Consume | sells = 68274
# Consume | sells = 68275
# Consume | sells = 68276
# Consume | sells = 68277
# Consume | sells = 68278
# Consume | sells = 68279
# Consume | sells = 68280
# Consume | sells = 68281
# Consume | sells = 68282
# Consume | sells = 68283
# Consume | sells = 68284
# Consume | sells = 68285
# Consume | sells = 68286
# Consume | sells = 68287
# Consume | sells = 68288
# Consume | sells = 68289
# Consume | sells = 68290
# Consume | sells = 68291
# Consume | sells = 68292
# Consume | sells = 68293
# Consume | sells = 68294
# Consume | sells = 68295
# Consume | sells = 68296
# Consume | sells = 68297
# Consume | sells = 68298
# Consume | sells = 68299
# Consume | sells = 68300
# Consume | sells = 68301
# Consume | sells = 68302
# Consume | sells = 68303
# Consume | sells = 68304
# Consume | sells = 68305
# Consume | sells = 68306
# Consume | sells = 68307
# Consume | sells = 68308
# Consume | sells = 68309
# Consume | sells = 68310
# Consume | sells = 68311
# Consume | sells = 68312
# Consume | sells = 68313
# Consume | sells = 68314
# Consume | sells = 68315
# Consume | sells = 68316
# Consume | sells = 68317
# Consume | sells = 68318
# Consume | sells = 68319
# Consume | sells = 68320
# Consume | sells = 68321
# Consume | sells = 68322
# Consume | sells = 68323
# Consume | sells = 68324
# Consume | sells = 68325
# Consume | sells = 68326
# Consume | sells = 68327
# Consume | sells = 68328
# Consume | sells = 68329
# Consume | sells = 68330
# Consume | sells = 68331
# Consume | sells = 68332
# Consume | sells = 68333
# Consume | sells = 68334
# Consume | sells = 68335
# Consume | sells = 68336
# Consume | sells = 68337
# Consume | sells = 68338
# Consume | sells = 68339
# Consume | sells = 68340
# Consume | sells = 68341
# Consume | sells = 68342
# Consume | sells = 68343
# Consume | sells = 68344
# Consume | sells = 68345
# Consume | sells = 68346
# Consume | sells = 68347
# Consume | sells = 68348
# Consume | sells = 68349
# Consume | sells = 68350
# Consume | sells = 68351
# Consume | sells = 68352
# Consume | sells = 68353
# Consume | sells = 68354
# Consume | sells = 68355
# Consume | sells = 68356
# Consume | sells = 68357
# Consume | sells = 68358
# Consume | sells = 68359
# Consume | sells = 68360
# Consume | sells = 68361
# Consume | sells = 68362
# Consume | sells = 68363
# Consume | sells = 68364
# Consume | sells = 68365
# Consume | sells = 68366
# Consume | sells = 68367
# Consume | sells = 68368
# Consume | sells = 68369
# Consume | sells = 68370
# Consume | sells = 68371
# Consume | sells = 68372
# Consume | sells = 68373
# Consume | sells = 68374
# Consume | sells = 68375
# Consume | sells = 68376
# Consume | sells = 68377
# Consume | sells = 68378
# Consume | sells = 68379
# Consume | sells = 68380
# Consume | sells = 68381
# Consume | sells = 68382
# Consume | sells = 68383
# Consume | sells = 68384
# Consume | sells = 68385
# Consume | sells = 68386
# Consume | sells = 68387
# Consume | sells = 68388
# Consume | sells = 68389
# Consume | sells = 68390
# Consume | sells = 68391
# Consume | sells = 68392
# Consume | sells = 68393
# Consume | sells = 68394
# Consume | sells = 68395
# Consume | sells = 68396
# Consume | sells = 68397
# Consume | sells = 68398
# Consume | sells = 68399
# Consume | sells = 68400
# Consume | sells = 68401
# Consume | sells = 68402
# Consume | sells = 68403
# Consume | sells = 68404
# Consume | sells = 68405
# Consume | sells = 68406
# Consume | sells = 68407
# Consume | sells = 68408
# Consume | sells = 68409
# Consume | sells = 68410
# Consume | sells = 68411
# Consume | sells = 68412
# Consume | sells = 68413
# Consume | sells = 68414
# Consume | sells = 68415
# Consume | sells = 68416
# Consume | sells = 68417
# Consume | sells = 68418
# Consume | sells = 68419
# Consume | sells = 68420
# Consume | sells = 68421
# Consume | sells = 68422
# Consume | sells = 68423
# Consume | sells = 68424
# Consume | sells = 68425
# Consume | sells = 68426
# Consume | sells = 68427
# Consume | sells = 68428
# Consume | sells = 68429
# Consume | sells = 68430
# Consume | sells = 68431
# Consume | sells = 68432
# Consume | sells = 68433
# Consume | sells = 68434
# Consume | sells = 68435
# Consume | sells = 68436
# Consume | sells = 68437
# Consume | sells = 68438
# Consume | sells = 68439
# Consume | sells = 68440
# Consume | sells = 68441
# Consume | sells = 68442
# Consume | sells = 68443
# Consume | sells = 68444
# Consume | sells = 68445
# Consume | sells = 68446
# Produce | products = 68742
# Produce | products = 68743
# Produce | products = 68744
# Produce | products = 68745
# Produce | products = 68746
# Produce | products = 68747
# Produce | products = 68748
# Produce | products = 68749
# Produce | products = 68750
# Produce | products = 68751
# Produce | products = 68752
# Produce | products = 68753
# Produce | products = 68754
# Produce | products = 68755
# Produce | products = 68756
# Produce | products = 68757
# Produce | products = 68758
# Produce | products = 68759
# Produce | products = 68760
# Produce | products = 68761
# Produce | products = 68762
# Produce | products = 68763
# Produce | products = 68764
# Produce | products = 68765
# Produce | products = 68766
# Produce | products = 68767
# Produce | products = 68768
# Produce | products = 68769
# Produce | products = 68770
# Produce | products = 68771
# Produce | products = 68772
# Produce | products = 68773
# Produce | products = 68774
# Produce | products = 68775
# Produce | products = 68776
# Produce | products = 68777
# Produce | products = 68778
# Produce | products = 68779
# Produce | products = 68780
# Produce | products = 68781
# Produce | products = 68782
# Produce | products = 68783
# Produce | products = 68784
# Produce | products = 68785
# Produce | products = 68786
# Produce | products = 68787
# Produce | products = 68788
# Produce | products = 68789
# Produce | products = 68790
# Produce | products = 68791
# Produce | products = 68792
# Produce | products = 68793
# Produce | products = 68794
# Produce | products = 68795
# Produce | products = 68796
# Produce | products = 68797
# Produce | products = 68798
# Produce | products = 68799
# Produce | products = 68800
# Produce | products = 68801
# Produce | products = 68802
# Produce | products = 68803
# Produce | products = 68804
# Produce | products = 68805
# Produce | products = 68806
# Produce | products = 68807
# Produce | products = 68808
# Produce | products = 68809
# Produce | products = 68810
# Produce | products = 68811
# Produce | products = 68812
# Produce | products = 68813
# Produce | products = 68814
# Produce | products = 68815
# Produce | products = 68816
# Produce | products = 68817
# Produce | products = 68818
# Produce | products = 68819
# Produce | products = 68820
# Produce | products = 68821
# Produce | products = 68822
# Produce | products = 68823
# Produce | products = 68824
# Produce | products = 68825
# Produce | products = 68826
# Produce | products = 68827
# Produce | products = 68828
# Produce | products = 68829
# Produce | products = 68830
# Produce | products = 68831
# Produce | products = 68832
# Produce | products = 68833
# Produce | products = 68834
# Produce | products = 68835
# Produce | products = 68836
# Produce | products = 68837
# Produce | products = 68838
# Produce | products = 68839
# Produce | products = 68840
# Produce | products = 68841
# Produce | products = 68842
# Produce | products = 68843
# Produce | products = 68844
# Produce | products = 68845
# Produce | products = 68846
# Produce | products = 68847
# Produce | products = 68848
# Produce | products = 68849
# Produce | products = 68850
# Produce | products = 68851
# Produce | products = 68852
# Produce | products = 68853
# Produce | products = 68854
# Produce | products = 68855
# Produce | products = 68856
# Produce | products = 68857
# Produce | products = 68858
# Produce | products = 68859
# Produce | products = 68860
# Produce | products = 68861
# Produce | products = 68862
# Produce | products = 68863
# Produce | products = 68864
# Produce | products = 68865
# Produce | products = 68866
# Produce | products = 68867
# Produce | products = 68868
# Produce | products = 68869
# Produce | products = 68870
# Produce | products = 68871
# Produce | products = 68872
# Produce | products = 68873
# Produce | products = 68874
# Produce | products = 68875
# Produce | products = 68876
# Produce | products = 68877
# Produce | products = 68878
# Produce | products = 68879
# Produce | products = 68880
# Produce | products = 68881
# Produce | products = 68882
# Produce | products = 68883
# Produce | products = 68884
# Produce | products = 68885
# Produce | products = 68886
# Produce | products = 68887
# Produce | products = 68888
# Produce | products = 68889
# Produce | products = 68890
# Produce | products = 68891
# Produce | products = 68892
# Produce | products = 68893
# Produce | products = 68894
# Produce | products = 68895
# Produce | products = 68896
# Produce | products = 68897
# Produce | products = 68898
# Produce | products = 68899
# Produce | products = 68900
# Produce | products = 68901
# Produce | products = 68902
# Produce | products = 68903
# Produce | products = 68904
# Produce | products = 68905
# Produce | products = 68906
# Produce | products = 68907
# Produce | products = 68908
# Produce | products = 68909
# Produce | products = 68910
# Produce | products = 68911
# Produce | products = 68912
# Produce | products = 68913
# Produce | products = 68914
# Produce | products = 68915
# Produce | products = 68916
# Produce | products = 68917
# Produce | products = 68918
# Produce | products = 68919
# Produce | products = 68920
# Produce | products = 68921
# Produce | products = 68922
# Produce | products = 68923
# Produce | products = 68924
# Produce | products = 68925
# Produce | products = 68926
# Produce | products = 68927
# Produce | products = 68928
# Produce | products = 68929
# Produce | products = 68930
# Produce | products = 68931
# Produce | products = 68932
# Produce | products = 68933
# Produce | products = 68934
# Produce | products = 68935
# Produce | products = 68936
# Produce | products = 68937
# Produce | products = 68938
# Produce | products = 68939
# Produce | products = 68940
# Produce | products = 68941
# Produce | products = 68942
# Produce | products = 68943
# Produce | products = 68944
# Produce | products = 68945
# Produce | products = 68946
# Produce | products = 68947
# Produce | products = 68948
# Produce | products = 68949
# Produce | products = 68950
# Produce | products = 68951
# Produce | products = 68952
# Produce | products = 68953
# Produce | products = 68954
# Produce | products = 68955
# Produce | products = 68956
# Produce | products = 68957
# Produce | products = 68958
# Produce | products = 68959
# Produce | products = 68960
# Produce | products = 68961
# Produce | products = 68962
# Produce | products = 68963
# Produce | products = 68964
# Produce | products = 68965
# Produce | products = 68966
# Produce | products = 68967
# Produce | products = 68968
# Produce | products = 68969
# Produce | products = 68970
# Produce | products = 68971
# Produce | products = 68972
# Produce | products = 68973
# Produce | products = 68974
# Produce | products = 68975
# Produce | products = 68976
# Produce | products = 68977
# Produce | products = 68978
# Produce | products = 68979
# Produce | products = 68980
# Produce | products = 68981
# Produce | products = 68982
# Produce | products = 68983
# Produce | products = 68984
# Produce | products = 68985
# Produce | products = 68986
# Produce | products = 68987
# Produce | products = 68988
# Produce | products = 68989
# Produce | products = 68990
# Produce | products = 68991
# Produce | products = 68992
# Produce | products = 68993
# Produce | products = 68994
# Produce | products = 68995
# Produce | products = 68996
# Produce | products = 68997
# Produce | products = 68998
# Produce | products = 68999
# Produce | products = 69000
# Produce | products = 69001
# Produce | products = 69002
# Produce | products = 69003
# Produce | products = 69004
# Produce | products = 69005
# Produce | products = 69006
# Produce | products = 69007
# Produce | products = 69008
# Produce | products = 69009
# Produce | products = 69010
# Produce | products = 69011
# Produce | products = 69012
# Produce | products = 69013
# Produce | products = 69014
# Produce | products = 69015
# Produce | products = 69016
# Produce | products = 69017
# Produce | products = 69018
# Produce | products = 69019
# Produce | products = 69020
# Produce | products = 69021
# Produce | products = 69022
# Produce | products = 69023
# Produce | products = 69024
# Produce | products = 69025
# Produce | products = 69026
# Produce | products = 69027
# Produce | products = 69028
# Produce | products = 69029
# Produce | products = 69030
# Produce | products = 69031
# Produce | products = 69032
# Produce | products = 69033
# Produce | products = 69034
# Produce | products = 69035
# Produce | products = 69036
# Produce | products = 69037
# Produce | products = 69038
# Produce | products = 69039
# Produce | products = 69040
# Produce | products = 69041
# Produce | products = 69042
# Produce | products = 69043
# Produce | products = 69044
# Produce | products = 69045
# Produce | products = 69046
# Produce | products = 69047
# Produce | products = 69048
# Produce | products = 69049
# Produce | products = 69050
# Produce | products = 69051
# Produce | products = 69052
# Produce | products = 69053
# Produce | products = 69054
# Produce | products = 69055
# Produce | products = 69056
# Produce | products = 69057
# Produce | products = 69058
# Produce | products = 69059
# Produce | products = 69060
# Produce | products = 69061
# Produce | products = 69062
# Produce | products = 69063
# Produce | products = 69064
# Produce | products = 69065
# Produce | products = 69066
# Produce | products = 69067
# Produce | products = 69068
# Produce | products = 69069
# Produce | products = 69070
# Produce | products = 69071
# Produce | products = 69072
# Produce | products = 69073
# Produce | products = 69074
# Produce | products = 69075
# Produce | products = 69076
# Produce | products = 69077
# Produce | products = 69078
# Produce | products = 69079
# Produce | products = 69080
# Produce | products = 69081
# Produce | products = 69082
# Produce | products = 69083
# Produce | products = 69084
# Produce | products = 69085
# Produce | products = 69086
# Produce | products = 69087
# Produce | products = 69088
# Produce | products = 69089
# Produce | products = 69090
# Produce | products = 69091
# Produce | products = 69092
# Produce | products = 69093
# Produce | products = 69094
# Produce | products = 69095
# Produce | products = 69096
# Produce | products = 69097
# Produce | products = 69098
# Produce | products = 69099
# Produce | products = 69100
# Produce | products = 69101
# Produce | products = 69102
# Produce | products = 69103
# Produce | products = 69104
# Produce | products = 69105
# Produce | products = 69106
# Produce | products = 69107
# Produce | products = 69108
# Produce | products = 69109
# Produce | products = 69110
# Produce | products = 69111
# Produce | products = 69112
# Produce | products = 69113
# Produce | products = 69114
# Produce | products = 69115
# Produce | products = 69116
# Produce | products = 69117
# Produce | products = 69118
# Produce | products = 69119
# Produce | products = 69120
# Produce | products = 69121
# Produce | products = 69122
# Produce | products = 69123
# Produce | products = 69124
# Produce | products = 69125
# Produce | products = 69126
# Produce | products = 69127
# Produce | products = 69128
# Produce | products = 69129
# Produce | products = 69130
# Produce | products = 69131
# Produce | products = 69132
# Produce | products = 69133
# Produce | products = 69134
# Produce | products = 69135
# Produce | products = 69136
# Produce | products = 69137
# Produce | products = 69138
# Produce | products = 69139
# Produce | products = 69140
# Produce | products = 69141
# Produce | products = 69142
# Produce | products = 69143
# Produce | products = 69144
# Produce | products = 69145
# Produce | products = 69146
# Produce | products = 69147
# Produce | products = 69148
# Produce | products = 69149
# Produce | products = 69150
# Produce | products = 69151
# Produce | products = 69152
# Produce | products = 69153
# Produce | products = 69154
# Produce | products = 69155
# Produce | products = 69156
# Produce | products = 69157
# Produce | products = 69158
# Produce | products = 69159
# Produce | products = 69160
# Produce | products = 69161
# Produce | products = 69162
# Produce | products = 69163
# Produce | products = 69164
# Produce | products = 69165
# Produce | products = 69166
# Produce | products = 69167
# Produce | products = 69168
# Produce | products = 69169
# Produce | products = 69170
# Produce | products = 69171
# Produce | products = 69172
# Produce | products = 69173
# Produce | products = 69174
# Produce | products = 69175
# Produce | products = 69176
# Produce | products = 69177
# Produce | products = 69178
# Produce | products = 69179
# Produce | products = 69180
# Produce | products = 69181
# Produce | products = 69182
# Produce | products = 69183
# Produce | products = 69184
# Produce | products = 69185
# Produce | products = 69186
# Produce | products = 69187
# Produce | products = 69188
# Produce | products = 69189
# Produce | products = 69190
# Produce | products = 69191
# Produce | products = 69192
# Produce | products = 69193
# Produce | products = 69194
# Produce | products = 69195
# Produce | products = 69196
# Produce | products = 69197
# Produce | products = 69198
# Produce | products = 69199
# Produce | products = 69200
# Produce | products = 69201
# Produce | products = 69202
# Produce | products = 69203
# Produce | products = 69204
# Produce | products = 69205
# Produce | products = 69206
# Produce | products = 69207
# Produce | products = 69208
# Produce | products = 69209
# Produce | products = 69210
# Produce | products = 69211
# Produce | products = 69212
# Produce | products = 69213
# Produce | products = 69214
# Produce | products = 69215
# Produce | products = 69216
# Produce | products = 69217
# Produce | products = 69218
# Produce | products = 69219
# Produce | products = 69220
# Produce | products = 69221
# Produce | products = 69222
# Produce | products = 69223
# Produce | products = 69224
# Produce | products = 69225
# Produce | products = 69226
# Produce | products = 69227
# Produce | products = 69228
# Produce | products = 69229
# Produce | products = 69230
# Produce | products = 69231
# Produce | products = 69232
# Produce | products = 69233
# Produce | products = 69234
# Produce | products = 69235
# Produce | products = 69236
# Produce | products = 69237
# Produce | products = 69238
# Produce | products = 69239
# Produce | products = 69240
# Produce | products = 69241
# Produce | products = 69242
# Produce | products = 69243
# Produce | products = 69244
# Produce | products = 69245
# Produce | products = 69246
# Produce | products = 69247
# Produce | products = 69248
# Produce | products = 69249
# Produce | products = 69250
# Produce | products = 69251
# Produce | products = 69252
# Produce | products = 69253
# Produce | products = 69254
# Produce | products = 69255
# Produce | products = 69256
# Produce | products = 69257
# Produce | products = 69258
# Produce | products = 69259
# Produce | products = 69260
# Produce | products = 69261
# Produce | products = 69262
# Produce | products = 69263
# Produce | products = 69264
# Produce | products = 69265
# Produce | products = 69266
# Produce | products = 69267
# Produce | products = 69268
# Produce | products = 69269
# Produce | products = 69270
# Produce | products = 69271
# Produce | products = 69272
# Produce | products = 69273
# Produce | products = 69274
# Produce | products = 69275
# Produce | products = 69276
# Produce | products = 69277
# Produce | products = 69278
# Produce | products = 69279
# Produce | products = 69280
# Produce | products = 69281
# Produce | products = 69282
# Produce | products = 69283
# Produce | products = 69284
# Produce | products = 69285
# Produce | products = 69286
# Produce | products = 69287
# Produce | products = 69288
# Produce | products = 69289
# Produce | products = 69290
# Produce | products = 69291
# Produce | products = 69292
# Produce | products = 69293
# Produce | products = 69294
# Produce | products = 69295
# Produce | products = 69296
# Produce | products = 69297
# Produce | products = 69298
# Produce | products = 69299
# Produce | products = 69300
# Produce | products = 69301
# Produce | products = 69302
# Produce | products = 69303
# Produce | products = 69304
# Produce | products = 69305
# Produce | products = 69306
# Produce | products = 69307
# Produce | products = 69308
# Produce | products = 69309
# Produce | products = 69310
# Produce | products = 69311
# Produce | products = 69312
# Produce | products = 69313
# Produce | products = 69314
# Produce | products = 69315
# Produce | products = 69316
# Produce | products = 69317
# Produce | products = 69318
# Produce | products = 69319
# Produce | products = 69320
# Produce | products = 69321
# Produce | products = 69322
# Produce | products = 69323
# Produce | products = 69324
# Produce | products = 69325
# Produce | products = 69326
# Produce | products = 69327
# Produce | products = 69328
# Produce | products = 69329
# Produce | products = 69330
# Produce | products = 69331
# Produce | products = 69332
# Produce | products = 69333
# Produce | products = 69334
# Produce | products = 69335
# Produce | products = 69336
# Produce | products = 69337
# Produce | products = 69338
# Produce | products = 69339
# Produce | products = 69340
# Produce | products = 69341
# Produce | products = 69342
# Produce | products = 69343
# Produce | products = 69344
# Produce | products = 69345
# Produce | products = 69346
# Produce | products = 69347
# Produce | products = 69348
# Produce | products = 69349
# Produce | products = 69350
# Produce | products = 69351
# Produce | products = 69352
# Produce | products = 69353
# Produce | products = 69354
# Produce | products = 69355
# Produce | products = 69356
# Produce | products = 69357
# Produce | products = 69358
# Produce | products = 69359
# Produce | products = 69360
# Produce | products = 69361
# Produce | products = 69362
# Produce | products = 69363
# Produce | products = 69364
# Produce | products = 69365
# Produce | products = 69366
# Produce | products = 69367
# Produce | products = 69368
# Produce | products = 69369
# Produce | products = 69370
# Produce | products = 69371
# Produce | products = 69372
# Produce | products = 69373
# Produce | products = 69374
# Produce | products = 69375
# Produce | products = 69376
# Produce | products = 69377
# Produce | products = 69378
# Produce | products = 69379
# Produce | products = 69380
# Produce | products = 69381
# Produce | products = 69382
# Produce | products = 69383
# Produce | products = 69384
# Produce | products = 69385
# Produce | products = 69386
# Produce | products = 69387
# Produce | products = 69388
# Produce | products = 69389
# Produce | products = 69390
# Produce | products = 69391
# Produce | products = 69392
# Produce | products = 69393
# Produce | products = 69394
# Produce | products = 69395
# Produce | products = 69396
# Produce | products = 69397
# Produce | products = 69398
# Produce | products = 69399
# Produce | products = 69400
# Produce | products = 69401
# Produce | products = 69402
# Produce | products = 69403
# Produce | products = 69404
# Produce | products = 69405
# Produce | products = 69406
# Produce | products = 69407
# Produce | products = 69408
# Produce | products = 69409
# Produce | products = 69410
# Produce | products = 69411
# Produce | products = 69412
# Produce | products = 69413
# Produce | products = 69414
# Produce | products = 69415
# Produce | products = 69416
# Produce | products = 69417
# Produce | products = 69418
# Produce | products = 69419
# Produce | products = 69420
# Produce | products = 69421
# Produce | products = 69422
# Produce | products = 69423
# Produce | products = 69424
# Produce | products = 69425
# Produce | products = 69426
# Produce | products = 69427
# Produce | products = 69428
# Produce | products = 69429
# Produce | products = 69430
# Produce | products = 69431
# Produce | products = 69432
# Produce | products = 69433
# Produce | products = 69434
# Produce | products = 69435
# Produce | products = 69436
# Produce | products = 69437
# Produce | products = 69438
# Produce | products = 69439
# Produce | products = 69440
# Produce | products = 69441
# Produce | products = 69442
# Produce | products = 69443
# Produce | products = 69444
# Produce | products = 69445
# Produce | products = 69446
# Produce | products = 69447
# Produce | products = 69448
# Produce | products = 69449
# Produce | products = 69450
# Produce | products = 69451
# Produce | products = 69452
# Produce | products = 69453
# Produce | products = 69454
# Produce | products = 69455
# Produce | products = 69456
# Produce | products = 69457
# Produce | products = 69458
# Produce | products = 69459
# Produce | products = 69460
# Produce | products = 69461
# Produce | products = 69462
# Produce | products = 69463
# Produce | products = 69464
# Produce | products = 69465
# Produce | products = 69466
# Produce | products = 69467
# Produce | products = 69468
# Produce | products = 69469
# Produce | products = 69470
# Produce | products = 69471
# Produce | products = 69472
# Produce | products = 69473
# Produce | products = 69474
# Produce | products = 69475
# Produce | products = 69476
# Produce | products = 69477
# Produce | products = 69478
# Produce | products = 69479
# Produce | products = 69480
# Produce | products = 69481
# Produce | products = 69482
# Produce | products = 69483
# Produce | products = 69484
# Produce | products = 69485
# Produce | products = 69486
# Produce | products = 69487
# Produce | products = 69488
# Produce | products = 69489
# Produce | products = 69490
# Produce | products = 69491
# Produce | products = 69492
# Produce | products = 69493
# Produce | products = 69494
# Produce | products = 69495
# Produce | products = 69496
# Produce | products = 69497
# Produce | products = 69498
# Produce | products = 69499
# Produce | products = 69500
# Produce | products = 69501
# Produce | products = 69502
# Produce | products = 69503
# Produce | products = 69504
# Produce | products = 69505
# Produce | products = 69506
# Produce | products = 69507
# Produce | products = 69508
# Produce | products = 69509
# Produce | products = 69510
# Produce | products = 69511
# Produce | products = 69512
# Produce | products = 69513
# Produce | products = 69514
# Produce | products = 69515
# Produce | products = 69516
# Produce | products = 69517
# Produce | products = 69518
# Produce | products = 69519
# Produce | products = 69520
# Produce | products = 69521
# Produce | products = 69522
# Produce | products = 69523
# Produce | products = 69524
# Produce | products = 69525
# Produce | products = 69526
# Produce | products = 69527
# Produce | products = 69528
# Produce | products = 69529
# Produce | products = 69530
# Produce | products = 69531
# Produce | products = 69532
# Produce | products = 69533
# Produce | products = 69534
# Produce | products = 69535
# Produce | products = 69536
# Produce | products = 69537
# Produce | products = 69538
# Produce | products = 69539
# Produce | products = 69540
# Produce | products = 69541
# Produce | products = 69542
# Produce | products = 69543
# Produce | products = 69544
# Produce | products = 69545
# Produce | products = 69546
# Produce | products = 69547
# Produce | products = 69548
# Produce | products = 69549
# Produce | products = 69550
# Produce | products = 69551
# Produce | products = 69552
# Produce | products = 69553
# Produce | products = 69554
# Produce | products = 69555
# Produce | products = 69556
# Produce | products = 69557
# Produce | products = 69558
# Produce | products = 69559
# Produce | products = 69560
# Produce | products = 69561
# Produce | products = 69562
# Produce | products = 69563
# Produce | products = 69564
# Produce | products = 69565
# Produce | products = 69566
# Produce | products = 69567
# Produce | products = 69568
# Produce | products = 69569
# Produce | products = 69570
# Produce | products = 69571
# Produce | products = 69572
# Produce | products = 69573
# Produce | products = 69574
# Produce | products = 69575
# Produce | products = 69576
# Produce | products = 69577
# Produce | products = 69578
# Produce | products = 69579
# Produce | products = 69580
# Produce | products = 69581
# Produce | products = 69582
# Produce | products = 69583
# Produce | products = 69584
# Produce | products = 69585
# Produce | products = 69586
# Produce | products = 69587
# Produce | products = 69588
# Produce | products = 69589
# Produce | products = 69590
# Produce | products = 69591
# Produce | products = 69592
# Produce | products = 69593
# Produce | products = 69594
# Produce | products = 69595
# Produce | products = 69596
# Produce | products = 69597
# Produce | products = 69598
# Produce | products = 69599
# Produce | products = 69600
# Produce | products = 69601
# Produce | products = 69602
# Produce | products = 69603
# Produce | products = 69604
# Produce | products = 69605
# Produce | products = 69606
# Produce | products = 69607
# Produce | products = 69608
# Produce | products = 69609
# Produce | products = 69610
# Produce | products = 69611
# Produce | products = 69612
# Produce | products = 69613
# Produce | products = 69614
# Produce | products = 69615
# Produce | products = 69616
# Produce | products = 69617
# Produce | products = 69618
# Produce | products = 69619
# Produce | products = 69620
# Produce | products = 69621
# Produce | products = 69622
# Produce | products = 69623
# Produce | products = 69624
# Produce | products = 69625
# Produce | products = 69626
# Produce | products = 69627
# Produce | products = 69628
# Produce | products = 69629
# Produce | products = 69630
# Produce | products = 69631
# Produce | products = 69632
# Produce | products = 69633
# Produce | products = 69634
# Produce | products = 69635
# Produce | products = 69636
# Produce | products = 69637
# Produce | products = 69638
# Produce | products = 69639
# Produce | products = 69640
# Produce | products = 69641
# Produce | products = 69642
# Produce | products = 69643
# Produce | products = 69644
# Produce | products = 69645
# Produce | products = 69646
# Produce | products = 69647
# Produce | products = 69648
# Produce | products = 69649
# Produce | products = 69650
# Produce | products = 69651
# Produce | products = 69652
# Produce | products = 69653
# Produce | products = 69654
# Produce | products = 69655
# Produce | products = 69656
# Produce | products = 69657
# Produce | products = 69658
# Produce | products = 69659
# Produce | products = 69660
# Produce | products = 69661
# Produce | products = 69662
# Produce | products = 69663
# Produce | products = 69664
# Produce | products = 69665
# Produce | products = 69666
# Produce | products = 69667
# Produce | products = 69668
# Produce | products = 69669
# Produce | products = 69670
# Produce | products = 69671
# Produce | products = 69672
# Produce | products = 69673
# Produce | products = 69674
# Produce | products = 69675
# Produce | products = 69676
# Produce | products = 69677
# Produce | products = 69678
# Produce | products = 69679
# Produce | products = 69680
# Produce | products = 69681
# Produce | products = 69682
# Produce | products = 69683
# Produce | products = 69684
# Produce | products = 69685
# Produce | products = 69686
# Produce | products = 69687
# Produce | products = 69688
# Produce | products = 69689
# Produce | products = 69690
# Produce | products = 69691
# Produce | products = 69692
# Produce | products = 69693
# Produce | products = 69694
# Produce | products = 69695
# Produce | products = 69696
# Produce | products = 69697
# Produce | products = 69698
# Produce | products = 69699
# Produce | products = 69700
# Produce | products = 69701
# Produce | products = 69702
# Produce | products = 69703
# Produce | products = 69704
# Produce | products = 69705
# Produce | products = 69706
# Produce | products = 69707
# ...
# Produce | products = 71440
# Produce | products = 71441
# Produce | products = 71442
# Produce | products = 71443
# Produce | products = 71444
# Produce | products = 71445
# Produce | products = 71446
# Produce | products = 71447
# Produce | products = 71448
# Produce | products = 71449
# Produce | products = 71450
# Produce | products = 71451
# Produce | products = 71452
# Produce | products = 71453
# Produce | products = 71454
# Produce | products = 71455
# Produce | products = 71456
# Produce | products = 71457
# Produce | products = 71458
# Produce | products = 71459
# Produce | products = 71460
# Produce | products = 71461
# Produce | products = 71462
# Produce | products = 71463
# Produce | products = 71464
# Produce | products = 71465
# Produce | products = 71466
# Produce | products = 71467
# Produce | products = 71468
# Produce | products = 71469
# Produce | products = 71470
# Produce | products = 71471
# Produce | products = 71472
# Produce | products = 71473
# Produce | products = 71474
# Produce | products = 71475
# Produce | products = 71476
# Produce | products = 71477
# Produce | products = 71478
# Produce | products = 71479
# Produce | products = 71480
# Produce | products = 71481
# Produce | products = 71482
# Produce | products = 71483
# Produce | products = 71484
# Produce | products = 71485
# Produce | products = 71486
# Produce | products = 71487
# Produce | products = 71488
# Produce | products = 71489
# Produce | products = 71490
# Produce | products = 71491
# Produce | products = 71492
# Produce | products = 71493
# Produce | products = 71494
# Produce | products = 71495
# Produce | products = 71496
# Produce | products = 71497
# Produce | products = 71498
# Produce | products = 71499
# Produce | products = 71500
# Produce | products = 71501
# Produce | products = 71502
# Produce | products = 71503
# Produce | products = 71504
# Produce | products = 71505
# Produce | products = 71506
# Produce | products = 71507
# Produce | products = 71508
# Produce | products = 71509
# Produce | products = 71510
# Produce | products = 71511
# Produce | products = 71512
# Produce | products = 71513
# Produce | products = 71514
# Produce | products = 71515
# Produce | products = 71516
# Produce | products = 71517
# Produce | products = 71518
# Produce | products = 71519
# Produce | products = 71520
# Produce | products = 71521
# Produce | products = 71522
# Produce | products = 71523
# Produce | products = 71524
# Produce | products = 71525
# Produce | products = 71526
# Produce | products = 71527
# Produce | products = 71528
# Produce | products = 71529
# Produce | products = 71530
# Produce | products = 71531
# Produce | products = 71532
# Produce | products = 71533
# Produce | products = 71534
# Produce | products = 71535
# Produce | products = 71536
# Produce | products = 71537
# Produce | products = 71538
# Produce | products = 71539
# Produce | products = 71540
# Produce | products = 71541
# Produce | products = 71542
# Produce | products = 71543
# Produce | products = 71544
# Produce | products = 71545
# Produce | products = 71546
# Produce | products = 71547
# Produce | products = 71548
# Produce | products = 71549
# Produce | products = 71550
# Produce | products = 71551
# Produce | products = 71552
# Produce | products = 71553
# Produce | products = 71554
# Produce | products = 71555
# Produce | products = 71556
# Produce | products = 71557
# Produce | products = 71558
# Produce | products = 71559
# Produce | products = 71560
# Produce | products = 71561
# Produce | products = 71562
# Produce | products = 71563
# Produce | products = 71564
# Produce | products = 71565
# Produce | products = 71566
# Produce | products = 71567
# Produce | products = 71568
# Produce | products = 71569
# Produce | products = 71570
# Produce | products = 71571
# Produce | products = 71572
# Produce | products = 71573
# Produce | products = 71574
# Produce | products = 71575
# Produce | products = 71576
# Produce | products = 71577
# Produce | products = 71578
# Produce | products = 71579
# Produce | products = 71580
# Produce | products = 71581
# Produce | products = 71582
# Produce | products = 71583
# Produce | products = 71584
# Produce | products = 71585
# Produce | products = 71586
# Produce | products = 71587
# Produce | products = 71588
# Produce | products = 71589
# Produce | products = 71590
# Produce | products = 71591
# Produce | products = 71592
# Produce | products = 71593
# Produce | products = 71594
# Produce | products = 71595
# Produce | products = 71596
# Produce | products = 71597
# Produce | products = 71598
# Produce | products = 71599
# Produce | products = 71600
# Produce | products = 71601
# Produce | products = 71602
# Produce | products = 71603
# Produce | products = 71604
# Produce | products = 71605
# Produce | products = 71606
# Produce | products = 71607
# Produce | products = 71608
# Produce | products = 71609
# Produce | products = 71610
# Produce | products = 71611
# Produce | products = 71612
# Produce | products = 71613
# Produce | products = 71614
# Produce | products = 71615
# Produce | products = 71616
# Produce | products = 71617
# Produce | products = 71618
# Produce | products = 71619
# Produce | products = 71620
# Produce | products = 71621
# Produce | products = 71622
# Produce | products = 71623
# Produce | products = 71624
# Produce | products = 71625
# Produce | products = 71626
# Produce | products = 71627
# Produce | products = 71628
# Produce | products = 71629
# Produce | products = 71630
# Produce | products = 71631
# Produce | products = 71632
# Produce | products = 71633
# Produce | products = 71634
# Produce | products = 71635
# Produce | products = 71636
# Produce | products = 71637
# Produce | products = 71638
# Produce | products = 71639
# Produce | products = 71640
# Produce | products = 71641
# Produce | products = 71642
# Produce | products = 71643
# Produce | products = 71644
# Produce | products = 71645
# Produce | products = 71646
# Produce | products = 71647
# Produce | products = 71648
# Produce | products = 71649
# Produce | products = 71650
# Produce | products = 71651
# Produce | products = 71652
# Produce | products = 71653
# Produce | products = 71654
# Produce | products = 71655
# Produce | products = 71656
# Produce | products = 71657
# Produce | products = 71658
# Produce | products = 71659
# Produce | products = 71660
# Produce | products = 71661
# Produce | products = 71662
# Produce | products = 71663
# Produce | products = 71664
# Produce | products = 71665
# Produce | products = 71666
# Produce | products = 71667
# Produce | products = 71668
# Produce | products = 71669
# Produce | products = 71670
# Produce | products = 71671
# Produce | products = 71672
# Produce | products = 71673
# Produce | products = 71674
# Produce | products = 71675
# Produce | products = 71676
# Produce | products = 71677
# Produce | products = 71678
# Produce | products = 71679
# Produce | products = 71680
# Produce | products = 71681
# Produce | products = 71682
# Produce | products = 71683
# Produce | products = 71684
# Produce | products = 71685
# Produce | products = 71686
# Produce | products = 71687
# Produce | products = 71688
# Produce | products = 71689
# Produce | products = 71690
# Produce | products = 71691
# Produce | products = 71692
# Produce | products = 71693
# Produce | products = 71694
# Produce | products = 71695
# Produce | products = 71696
# Produce | products = 71697
# Produce | products = 71698
# Produce | products = 71699
# Produce | products = 71700
# Produce | products = 71701
# Produce | products = 71702
# Produce | products = 71703
# Produce | products = 71704
# Produce | products = 71705
# Produce | products = 71706
# Produce | products = 71707
# Produce | products = 71708
# Produce | products = 71709
# Produce | products = 71710
# Produce | products = 71711
# Produce | products = 71712
# Produce | products = 71713
# Produce | products = 71714
# Produce | products = 71715
# Produce | products = 71716
# Produce | products = 71717
# Produce | products = 71718
# Produce | products = 71719
# Produce | products = 71720
# Produce | products = 71721
# Produce | products = 71722
# Produce | products = 71723
# Produce | products = 71724
# Produce | products = 71725
# Produce | products = 71726
# Produce | products = 71727
# Produce | products = 71728
# Produce | products = 71729
# Produce | products = 71730
# Produce | products = 71731
# Produce | products = 71732
# Produce | products = 71733
# Produce | products = 71734
# Produce | products = 71735
# Produce | products = 71736
# Produce | products = 71737
# Produce | products = 71738
# Produce | products = 71739
# Produce | products = 71740
# Produce | products = 71741
# Produce | products = 71742
# Produce | products = 71743
# Produce | products = 71744
# Produce | products = 71745
# Produce | products = 71746
# Produce | products = 71747
# Produce | products = 71748
# Produce | products = 71749
# Produce | products = 71750
# Produce | products = 71751
# Produce | products = 71752
# Produce | products = 71753
# Produce | products = 71754
# Produce | products = 71755
# Produce | products = 71756
# Produce | products = 71757
# Produce | products = 71758
# Produce | products = 71759
# Produce | products = 71760
# Produce | products = 71761
# Produce | products = 71762
# Produce | products = 71763
# Produce | products = 71764
# Produce | products = 71765
# Produce | products = 71766
# Produce | products = 71767
# Produce | products = 71768
# Produce | products = 71769
# Produce | products = 71770
# Produce | products = 71771
# Produce | products = 71772
# Produce | products = 71773
# Produce | products = 71774
# Produce | products = 71775
# Produce | products = 71776
# Produce | products = 71777
# Produce | products = 71778
# Produce | products = 71779
# Produce | products = 71780
# Produce | products = 71781
# Produce | products = 71782
# Produce | products = 71783
# Produce | products = 71784
# Produce | products = 71785
# Produce | products = 71786
# Produce | products = 71787
# Produce | products = 71788
# Produce | products = 71789
# Produce | products = 71790
# Produce | products = 71791
# Produce | products = 71792
# Produce | products = 71793
# Produce | products = 71794
# Produce | products = 71795
# Produce | products = 71796
# Produce | products = 71797
# Produce | products = 71798
# Produce | products = 71799
# Produce | products = 71800
# Produce | products = 71801
# Produce | products = 71802
# Produce | products = 71803
# Produce | products = 71804
# Produce | products = 71805
# Produce | products = 71806
# Produce | products = 71807
# Produce | products = 71808
# Produce | products = 71809
# Produce | products = 71810
# Produce | products = 71811
# Produce | products = 71812
# Produce | products = 71813
# Produce | products = 71814
# Produce | products = 71815
# Produce | products = 71816
# Produce | products = 71817
# Produce | products = 71818
# Produce | products = 71819
# Produce | products = 71820
# Produce | products = 71821
# Produce | products = 71822
# Produce | products = 71823
# Produce | products = 71824
# Produce | products = 71825
# Produce | products = 71826
# Produce | products = 71827
# Produce | products = 71828
# Produce | products = 71829
# Produce | products = 71830
# Produce | products = 71831
# Produce | products = 71832
# Produce | products = 71833
# Produce | products = 71834
# Produce | products = 71835
# Produce | products = 71836
# Produce | products = 71837
# Produce | products = 71838
# Produce | products = 71839
# Produce | products = 71840
# Produce | products = 71841
# Produce | products = 71842
# Produce | products = 71843
# Produce | products = 71844
# Produce | products = 71845
# Produce | products = 71846
# Produce | products = 71847
# Produce | products = 71848
# Produce | products = 71849
# Produce | products = 71850
# Produce | products = 71851
# Produce | products = 71852
# Produce | products = 71853
# Produce | products = 71854
# Produce | products = 71855
# Produce | products = 71856
# Produce | products = 71857
# Produce | products = 71858
# Produce | products = 71859
# Produce | products = 71860
# Produce | products = 71861
# Produce | products = 71862
# Produce | products = 71863
# Produce | products = 71864
# Produce | products = 71865
# Produce | products = 71866
# Produce | products = 71867
# Produce | products = 71868
# Produce | products = 71869
# Produce | products = 71870
# Produce | products = 71871
# Produce | products = 71872
# Produce | products = 71873
# Produce | products = 71874
# Produce | products = 71875
# Produce | products = 71876
# Produce | products = 71877
# Produce | products = 71878
# Produce | products = 71879
# Produce | products = 71880
# Produce | products = 71881
# Produce | products = 71882
# Produce | products = 71883
# Produce | products = 71884
# Produce | products = 71885
# Produce | products = 71886
# Produce | products = 71887
# Produce | products = 71888
# Produce | products = 71889
# Produce | products = 71890
# Produce | products = 71891
# Produce | products = 71892
# Produce | products = 71893
# Produce | products = 71894
# Produce | products = 71895
# Produce | products = 71896
# Produce | products = 71897
# Produce | products = 71898
# Produce | products = 71899
# Produce | products = 71900
# Produce | products = 71901
# Produce | products = 71902
# Produce | products = 71903
# Produce | products = 71904
# Produce | products = 71905
# Produce | products = 71906
# Produce | products = 71907
# Produce | products = 71908
# Produce | products = 71909
# Produce | products = 71910
# Produce | products = 71911
# Produce | products = 71912
# Produce | products = 71913
# Produce | products = 71914
# Produce | products = 71915
# Produce | products = 71916
# Produce | products = 71917
# Produce | products = 71918
# Produce | products = 71919
# Produce | products = 71920
# Produce | products = 71921
# Produce | products = 71922
# Produce | products = 71923
# Consume | sells = 69232
# Consume | sells = 69233
# Consume | sells = 69234
# Consume | sells = 69235
# Consume | sells = 69236
# Consume | sells = 69237
# Consume | sells = 69238
# Consume | sells = 69239
# Consume | sells = 69240
# Consume | sells = 69241
# Consume | sells = 69242
# Consume | sells = 69243
# Consume | sells = 69244
# Consume | sells = 69245
# Consume | sells = 69246
# Consume | sells = 69247
# Consume | sells = 69248
# Consume | sells = 69249
# Consume | sells = 69250
# Consume | sells = 69251
# Consume | sells = 69252
# Consume | sells = 69253
# Consume | sells = 69254
# Consume | sells = 69255
# Consume | sells = 69256
# Consume | sells = 69257
# Consume | sells = 69258
# Consume | sells = 69259
# Consume | sells = 69260
# Consume | sells = 69261
# Consume | sells = 69262
# Consume | sells = 69263
# Consume | sells = 69264
# Consume | sells = 69265
# Consume | sells = 69266
# Consume | sells = 69267
# Consume | sells = 69268
# Consume | sells = 69269
# Consume | sells = 69270
# Consume | sells = 69271
# Consume | sells = 69272
# Consume | sells = 69273
# Consume | sells = 69274
# Consume | sells = 69275
# Consume | sells = 69276
# Consume | sells = 69277
# Consume | sells = 69278
# Consume | sells = 69279
# Consume | sells = 69280
# Consume | sells = 69281
# Consume | sells = 69282
# Consume | sells = 69283
# Consume | sells = 69284
# Consume | sells = 69285
# Consume | sells = 69286
# Consume | sells = 69287
# Consume | sells = 69288
# Consume | sells = 69289
# Consume | sells = 69290
# Consume | sells = 69291
# Consume | sells = 69292
# Consume | sells = 69293
# Consume | sells = 69294
# Consume | sells = 69295
# Consume | sells = 69296
# Consume | sells = 69297
# Consume | sells = 69298
# Consume | sells = 69299
# Consume | sells = 69300
# Consume | sells = 69301
# Consume | sells = 69302
# Consume | sells = 69303
# Consume | sells = 69304
# Consume | sells = 69305
# Consume | sells = 69306
# Consume | sells = 69307
# Consume | sells = 69308
# Consume | sells = 69309
# Consume | sells = 69310
# Consume | sells = 69311
# Consume | sells = 69312
# Consume | sells = 69313
# Consume | sells = 69314
# Consume | sells = 69315
# Consume | sells = 69316
# Consume | sells = 69317
# Consume | sells = 69318
# Consume | sells = 69319
# Consume | sells = 69320
# Consume | sells = 69321
# Consume | sells = 69322
# Consume | sells = 69323
# Consume | sells = 69324
# Consume | sells = 69325
# Consume | sells = 69326
# Consume | sells = 69327
# Consume | sells = 69328
# Consume | sells = 69329
# Consume | sells = 69330
# Consume | sells = 69331
# Consume | sells = 69332
# Consume | sells = 69333
# Consume | sells = 69334
# Consume | sells = 69335
# Consume | sells = 69336
# Consume | sells = 69337
# Consume | sells = 69338
# Consume | sells = 69339
# Consume | sells = 69340
# Consume | sells = 69341
# Consume | sells = 69342
# Consume | sells = 69343
# Consume | sells = 69344
# Consume | sells = 69345
# Consume | sells = 69346
# Consume | sells = 69347
# Consume | sells = 69348
# Consume | sells = 69349
# Consume | sells = 69350
# Consume | sells = 69351
# Consume | sells = 69352
# ^C
